# %% [markdown]
# An Exploratory Data Analysis - Deadly Earthquakes
# This project is related an exploratory data analysis (EDA).
#
# In that, I will cover main 3 components :
#
# Data Collection : The first step is to gather data on the deadly earthquake. This may include data on the earthquake's location, magnitude, duration, depth, and impact on the affected region.
#
# Data Cleaning and Preparation: Once the data is collected, the next step is to clean and prepare it for analysis. This may include handling missing values, outliers, and data formatting issues.
#
# Exploratory Data Analysis: After preparing the data, the next step is to perform exploratory data analysis (EDA) to gain insights into the characteristics of the earthquake. This may include computing summary statistics, visualizing the data using charts and maps, and identifying any correlations or patterns in the data.
#
# Importing all the necessary libraries :

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/Users/adityakansara/Desktop/untitled folder/deadliest_earthquakes.csv')

# %% [markdown]
# To know the last 5 data of dataset :

# %%
df.head()
# Out:
#    Unnamed: 0  Year Magnitude                   Location Depth (km)   MMI  \
# 0           0  1939       7.8  Turkey, Erzincan Province       20.0   XII
# 1           1  1940       7.7    Romania, Vrancea County      133.0     X
# 2           2  1941       5.8      Yemen, Razih District       35.0  VIII
# 3           3  1942       7.0              Turkey, Erbaa       10.0    IX
# 4           4  1943   7.5-7.7            Turkey, Çankırı       20.0    XI
#
#                                                Notes  \
# 0                At least 32,700 people were killed.
# 1  1,000 people were killed in Romania and Moldov...
# 2                          1,200 people were killed.
# 3                          3,000 people were killed.
# 4        Between 2,824 and 5,000 people were killed.
#
#                           Event         Date
# 0      1939 Erzincan earthquake  December 27
# 1       1940 Vrancea earthquake  November 10
# 2   1941 Jabal Razih earthquake   January 11
# 3  1942 Niksar–Erbaa earthquake  December 20
# 4   1943 Tosya–Ladik earthquake  November 27

# %%
df.tail()
# Out:
#     Unnamed: 0  Year Magnitude  \
# 79          79  2019       6.4
# 80          80  2020       7.0
# 81          81  2021       7.2
# 82          82  2022       6.0
# 83          83  2023       7.8
#
#                                              Location Depth (km)   MMI  \
# 79                                    Albania, Durrës       10.0  VIII
# 80                            Greece TurkeyAegean Sea       21.0  VIII
# 81                                      Haiti, Nippes       10.0    IX
# 82                                 Afghanistan, Khost       10.0  VIII
# 83  Turkey, Southeastern Anatolia Syria, Aleppo an...  17.9 10.0   XII
#
#                                                 Notes  \
# 79  At least 51 people killed, 3,000 people injure...
# 80  At least 119 people killed, 1,096 people were ...
# 81  At least 2,248 people killed, 12,763 people we...
# 82  At least 1,163 people were killed and 6,027 ot...
# 83  A Mw 7.8 earthquake hit followed by a Mw 7.7 a...
#
#                                Event         Date
# 79           2019 Albania earthquake  November 26
# 80        2020 Aegean Sea earthquake   October 30
# 81             2021 Haiti earthquake    August 14
# 82  June 2022 Afghanistan earthquake      June 21
# 83      2023 Turkey–Syria earthquake   February 6

# %%
df.shape
# Out:
# (84, 9)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Magnitude', 'Location', 'Depth (km)', 'MMI',
#        'Notes', 'Event', 'Date'],
#       dtype='object')

# %% [markdown]
# To know if there is any duplicate values in the dataset :

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# To know if there is any null values in the dataset :

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Year          0
# Magnitude     0
# Location      0
# Depth (km)    0
# MMI           1
# Notes         0
# Event         0
# Date          0
# dtype: int64

# %% [markdown]
# To know the information in the dataset:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  84 non-null     int64
#  1   Year        84 non-null     int64
#  2   Magnitude   84 non-null     object
#  3   Location    84 non-null     object
#  4   Depth (km)  84 non-null     object
#  5   MMI         83 non-null     object
#  6   Notes       84 non-null     object
#  7   Event       84 non-null     object
#  8   Date        84 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 6.0+ KB

# %% [markdown]
# To know count, mean , std, min-max, 25%, 50%, 75% in dataset :

# %%
df.describe()
# Out:
#        Unnamed: 0         Year
# count   84.000000    84.000000
# mean    41.500000  1981.404762
# std     24.392622    24.544093
# min      0.000000  1939.000000
# 25%     20.750000  1960.750000
# 50%     41.500000  1981.500000
# 75%     62.250000  2002.250000
# max     83.000000  2023.000000

# %% [markdown]
# To know all the unique values in the dataset :

# %%
df.nunique()
# Out:
# Unnamed: 0    84
# Year          84
# Magnitude     33
# Location      80
# Depth (km)    39
# MMI           10
# Notes         84
# Event         84
# Date          75
# dtype: int64

# %%
df.head(2)
# Out:
#    Unnamed: 0  Year Magnitude                   Location Depth (km)  MMI  \
# 0           0  1939       7.8  Turkey, Erzincan Province       20.0  XII
# 1           1  1940       7.7    Romania, Vrancea County      133.0    X
#
#                                                Notes  \
# 0                At least 32,700 people were killed.
# 1  1,000 people were killed in Romania and Moldov...
#
#                       Event         Date
# 0  1939 Erzincan earthquake  December 27
# 1   1940 Vrancea earthquake  November 10

# %% [markdown]
# To check the total value counts in the dataset :

# %%
df['MMI'].unique()
# Out:
# array(['XII', 'X', 'VIII', 'IX', 'XI', nan, 'VII', 'VIII & IX', 'VI[4]',
#        'VII[6]', 'VIII[7]'], dtype=object)

# %%
df['MMI'].value_counts()
# Out:
# MMI
# IX           29
# X            18
# VIII         15
# XI            9
# VII           6
# XII           2
# VIII & IX     1
# VI[4]         1
# VII[6]        1
# VIII[7]       1
# Name: count, dtype: int64

# %%
df ['Magnitude'].unique()
# Out:
# array(['7.8', '7.7', '5.8', '7.0', '7.5-7.7', '8.1', '7.3', '7.5', '8.6',
#        '6.5', '9.0', '6.7', '7.4', '6.4', '6.1', '9.2', '6.8', '6.6',
#        '7.1', '7.9', '6.9', '7.6', '8.2', '6.6 & 7.1', '6.2', '6.3',
#        '8.0', '5.7', '5.3', '7.4 & 6.1', '9.1', '7.2', '6.0'],
#       dtype=object)

# %% [markdown]
# Data Visualization
# I have added some visualization graphs and charts to show the data in a more understanable way!
#
# 1. Countplot

# %%
plt.figure(figsize = (15,6))
sns.countplot(x='MMI', data = df, palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/adityakansara/Desktop/untitled folder/deadliest_earthquakes.csv')

# %% [markdown]
# 2. Pie Chart

# %%
plt.figure(figsize= (30,20))
plt.pie(df['MMI'].value_counts(), labels = df['MMI'].value_counts().index, autopct = '%1.1f%%', textprops= {'fontsize' : 25, 'color' : 'black', 'weight' : 'normal', 'family' : 'cursive'})

hfont = {'fontname': 'serif', 'weight' : 'black'}
plt.title('MMI', size=20 , **hfont)
plt.show()

# %%
df.head(2)
# Out:
#    Unnamed: 0  Year Magnitude                   Location Depth (km)  MMI  \
# 0           0  1939       7.8  Turkey, Erzincan Province       20.0  XII
# 1           1  1940       7.7    Romania, Vrancea County      133.0    X
#
#                                                Notes  \
# 0                At least 32,700 people were killed.
# 1  1,000 people were killed in Romania and Moldov...
#
#                       Event         Date
# 0  1939 Erzincan earthquake  December 27
# 1   1940 Vrancea earthquake  November 10

# %% [markdown]
# 3. Histplot
# Here , I have used 'Magnitude' column for visualisation

# %%
plt.figure(figsize= (15,6))
sns.histplot(df['Magnitude'], kde = True, palette = 'hls') # kde is used to show the continous line kind of standard deviation line
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Now, I have used 'Depth' column for visualisation

# %%
plt.figure(figsize = (15,5))
sns.histplot(df['Depth (km)'], kde= True , palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Now, I have used 'MMI' column for visualisation

# %%
plt.figure(figsize = (15,6))
sns.histplot(df['MMI'], kde = True, palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# 4. Scatterplot

# %%
plt.figure(figsize = (15,6))
sns.scatterplot(x = df['Magnitude'], y = df['Depth (km)'],palette= 'hls')
plt.show()

# %% [markdown]
# To compare from one column to two different axis, use 'hue' function. This means the below chart is accroding to MMI to two different axis's information which is Magnitude and depth.

# %%
plt.figure(figsize= (15,6))
sns.scatterplot (x= df['Magnitude'], y= df['Depth (km)'], hue = df['MMI'] , palette = 'hls')
plt.show()

# %% [markdown]
# 5. Lineplot

# %%
plt.figure(figsize = (15,6))
sns.lineplot(x= df['Magnitude'], y= df['Depth (km)'],  palette = 'hls')
plt.show()

# %% [markdown]
# To get the any string value from any object datatype

# %%
plt.figure(figsize = (15,6))
sns.lineplot(x= df['Magnitude'], y= df['Depth (km)'], hue = df['MMI'],  palette = 'hls')
plt.show()

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# Year           int64
# Magnitude     object
# Location      object
# Depth (km)    object
# MMI           object
# Notes         object
# Event         object
# Date          object
# dtype: object

# %%
df.head(5)
# Out:
#    Unnamed: 0  Year Magnitude                   Location Depth (km)   MMI  \
# 0           0  None       7.8  Turkey, Erzincan Province       20.0   XII
# 1           1  None       7.7    Romania, Vrancea County      133.0     X
# 2           2  None       5.8      Yemen, Razih District       35.0  VIII
# 3           3  None       7.0              Turkey, Erbaa       10.0    IX
# 4           4  None   7.5-7.7            Turkey, Çankırı       20.0    XI
#
#                                                Notes  \
# 0                At least 32,700 people were killed.
# 1  1,000 people were killed in Romania and Moldov...
# 2                          1,200 people were killed.
# 3                          3,000 people were killed.
# 4        Between 2,824 and 5,000 people were killed.
#
#                           Event         Date     Month Day
# 0      1939 Erzincan earthquake  December 27  December  27
# 1       1940 Vrancea earthquake  November 10  November  10
# 2   1941 Jabal Razih earthquake   January 11   January  11
# 3  1942 Niksar–Erbaa earthquake  December 20  December  20
# 4   1943 Tosya–Ladik earthquake  November 27  November  27

# %%
# Check how many components each date splits into
df['Date'].str.split(' ', expand=True).apply(lambda x: len(x), axis=1).value_counts()
# Out:
# 5    84
# Name: count, dtype: int64

# %%
def split_date(date_str):
    parts = date_str.split()
    if len(parts) == 2:
        return parts[0], parts[1], None  # Month, Day, None for Year
    elif len(parts) == 3:
        return parts[0], parts[1], parts[2]  # Month, Day, Year
    else:
        return None, None, None  # Unexpected format

# Apply the function and create new columns
df['Month'], df['Day'], df['Year'] = zip(*df['Date'].apply(split_date))

# %%
df.head()
# Out:
#    Unnamed: 0  Year Magnitude                   Location Depth (km)   MMI  \
# 0           0  None       7.8  Turkey, Erzincan Province       20.0   XII
# 1           1  None       7.7    Romania, Vrancea County      133.0     X
# 2           2  None       5.8      Yemen, Razih District       35.0  VIII
# 3           3  None       7.0              Turkey, Erbaa       10.0    IX
# 4           4  None   7.5-7.7            Turkey, Çankırı       20.0    XI
#
#                                                Notes  \
# 0                At least 32,700 people were killed.
# 1  1,000 people were killed in Romania and Moldov...
# 2                          1,200 people were killed.
# 3                          3,000 people were killed.
# 4        Between 2,824 and 5,000 people were killed.
#
#                           Event         Date     Month Day
# 0      1939 Erzincan earthquake  December 27  December  27
# 1       1940 Vrancea earthquake  November 10  November  10
# 2   1941 Jabal Razih earthquake   January 11   January  11
# 3  1942 Niksar–Erbaa earthquake  December 20  December  20
# 4   1943 Tosya–Ladik earthquake  November 27  November  27

# %% [markdown]
# Now I have added a new dataframe called df_sorted_magnitude plus in that we can see how to sort values too.

# %%
df_sorted_magnitude = df.sort_values('Magnitude',ascending = False)

# %%
df_sorted_magnitude.head()
# Out:
#     Unnamed: 0  Year Magnitude  \
# 24          24  None       9.2
# 71          71  None       9.1
# 64          64  None       9.1
# 12          12  None       9.0
# 10          10  None       8.6
#
#                                            Location Depth (km) MMI  \
# 24                            United States, Alaska       25.0  XI
# 71                           Japan, Sendai offshore       29.0  IX
# 64                      Indonesia, Sumatra offshore       30.0  IX
# 12  Soviet Union, Russian Soviet Socialist Republic       21.6  XI
# 10                                     India, Assam       15.0  XI
#
#                                                 Notes  \
# 24  It is the largest earthquake ever recorded in ...
# 71  At least 19,747 people killed, 2,556 missing, ...
# 64  This is the third largest earthquake in the wo...
# 12  Between 2,336 and 20,000 people were killed an...
# 10  It is the largest earthquake on land and the l...
#
#                                  Event         Date     Month Day
# 24              1964 Alaska earthquake     March 27     March  27
# 71  2011 Tōhoku earthquake and tsunami     March 11     March  11
# 64        2004 Indian Ocean earthquake  December 26  December  26
# 12      1952 Severo-Kurilsk earthquake   November 5  November   5
# 10         1950 Assam–Tibet earthquake    August 15    August  15

# %%
df_sorted_magnitude.tail()
# Out:
#     Unnamed: 0  Year Magnitude                                       Location  \
# 82          82  None       6.0                             Afghanistan, Khost
# 2            2  None       5.8                          Yemen, Razih District
# 20          20  None       5.8                           Morocco, Souss-Massa
# 46          46  None       5.7                      El Salvador, San Salvador
# 49          49  None       5.3  Soviet Union, Tajik Soviet Socialist Republic
#
#    Depth (km)   MMI                                              Notes  \
# 82       10.0  VIII  At least 1,163 people were killed and 6,027 ot...
# 2        35.0  VIII                          1,200 people were killed.
# 20       15.0     X  Worst earthquake in Moroccan history. Between ...
# 46       10.0    IX  1,000–1,500 were killed and 10,000–20,000 inju...
# 49       33.0   VII  More than 274 people were killed. Most of the ...
#
#                                Event         Date     Month Day
# 82  June 2022 Afghanistan earthquake      June 21      June  21
# 2        1941 Jabal Razih earthquake   January 11   January  11
# 20            1960 Agadir earthquake  February 29  February  29
# 46      1986 San Salvador earthquake   October 10   October  10
# 49            1989 Gissar earthquake   January 23   January  23

# %% [markdown]
# Now same I will do for depth for sorting values.

# %%
df_sorted_depth = df.sort_values('Depth (km)', ascending = False)

# %%
df_sorted_depth.head()
# Out:
#     Unnamed: 0  Year Magnitude                    Location Depth (km)     MMI  \
# 69          69  None       7.6  Indonesia, Padang offshore       90.0  VII[6]
# 72          72  None       6.4       Iran, East Azerbaijan        9.0    VIII
# 37          37  None       7.5            Romania, Vrancea       85.3      IX
# 11          11  None       6.5        El Salvador offshore       85.0     NaN
# 75          75  None       7.8      Nepal, Gorkha District        8.2       X
#
#                                                 Notes  \
# 69  At least 1,115 people killed, 2,181 injured, 1...
# 72  At least 306 people killed, 3,037 injured, 4 v...
# 37  1,578 people were killed (1,424 of them in Buc...
# 11                          1,100 people were killed.
# 75  At least 9,182 people killed, 25,482 injured, ...
#
#                                Event          Date      Month Day
# 69           2009 Sumatra earthquake  September 30  September  30
# 72  2012 East Azerbaijan earthquakes     August 11     August  11
# 37           1977 Vrancea earthquake       March 4      March   4
# 11       1951 El Salvador earthquake         May 6        May   6
# 75       April 2015 Nepal earthquake      April 25      April  25

# %%
df_sorted_depth.tail()
# Out:
#     Unnamed: 0  Year Magnitude                   Location Depth (km)   MMI  \
# 31          31  None       6.9             Turkey, Bingöl       10.0  VIII
# 32          32  None       6.6                 Iran, Fars       10.0    IX
# 47          47  None       7.1         Ecuador, Sucumbíos       10.0    IX
# 46          46  None       5.7  El Salvador, San Salvador       10.0    IX
# 42          42  None       6.2        North Yemen, Dhamar       10.0  VIII
#
#                                                 Notes  \
# 31  875 killed. 5,583 houses heavily damaged, 3,41...
# 32  The estimated number of deaths is 5,374, with ...
# 47     More than 1,000 were killed and 5,000 missing.
# 46  1,000–1,500 were killed and 10,000–20,000 inju...
# 42  2,800 people were killed, 1,500 injured and 70...
#
#                            Event         Date     Month Day
# 31        1971 Bingöl earthquake       May 22       May  22
# 32           1972 Qir earthquake     April 10     April  10
# 47      1987 Ecuador earthquakes      March 6     March   6
# 46  1986 San Salvador earthquake   October 10   October  10
# 42   1982 North Yemen earthquake  December 13  December  13

# %% [markdown]
# To remove any NaN values from dataset and use the same dataframe name

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Year          0
# Magnitude     0
# Location      0
# Depth (km)    0
# MMI           0
# Notes         0
# Event         0
# Date          0
# Month         0
# Day           0
# dtype: int64
